# %% [markdown]
# <a href="https://colab.research.google.com/github/ZohaAsghar/Fraud-detection/blob/main/Fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import  os

# %%
import kagglehub
path = kagglehub.dataset_download("miadul/credit-card-fraud-detection-dataset")
# Out:
# Using Colab cache for faster access to the 'credit-card-fraud-detection-dataset' dataset.

# %%
df=pd.read_csv(os.path.join(path,"credit_card_fraud_10k.csv"))

# %%
df
# Out:
#       transaction_id  amount  transaction_hour merchant_category  \
# 0                  1   84.47                22       Electronics
# 1                  2  541.82                 3            Travel
# 2                  3  237.01                17           Grocery
# 3                  4  164.33                 4           Grocery
# 4                  5   30.53                15              Food
# ...              ...     ...               ...               ...
# 9995            9996  350.91                22              Food
# 9996            9997  410.04                 5          Clothing
# 9997            9998  527.75                21       Electronics
# 9998            9999   91.20                 2       Electronics
# 9999           10000   44.06                 2          Clothing
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 0                       0                  0                  66
# ...

# %%
df.describe()
# Out:
#        transaction_id        amount  transaction_hour  foreign_transaction  \
# count     10000.00000  10000.000000      10000.000000         10000.000000
# mean       5000.50000    175.949849         11.593300             0.097800
# std        2886.89568    175.392827          6.922708             0.297059
# min           1.00000      0.000000          0.000000             0.000000
# 25%        2500.75000     50.905000          6.000000             0.000000
# 50%        5000.50000    122.095000         12.000000             0.000000
# 75%        7500.25000    242.480000         18.000000             0.000000
# max       10000.00000   1471.040000         23.000000             1.000000
#
#        location_mismatch  device_trust_score  velocity_last_24h  \
# count       10000.000000        10000.000000       10000.000000
# mean            0.085700           61.798900           2.008900
# std             0.279935           21.487053           1.432559
# ...

# %%
df.head()
# Out:
#    transaction_id  amount  transaction_hour merchant_category  \
# 0               1   84.47                22       Electronics
# 1               2  541.82                 3            Travel
# 2               3  237.01                17           Grocery
# 3               4  164.33                 4           Grocery
# 4               5   30.53                15              Food
#
#    foreign_transaction  location_mismatch  device_trust_score  \
# 0                    0                  0                  66
# 1                    1                  0                  87
# 2                    0                  0                  49
# 3                    0                  1                  72
# 4                    0                  0                  79
#
#    velocity_last_24h  cardholder_age  is_fraud
# 0                  3              40         0
# 1                  1              64         0
# 2                  1              61         0
# ...

# %%
df.tail()
# Out:
#       transaction_id  amount  transaction_hour merchant_category  \
# 9995            9996  350.91                22              Food
# 9996            9997  410.04                 5          Clothing
# 9997            9998  527.75                21       Electronics
# 9998            9999   91.20                 2       Electronics
# 9999           10000   44.06                 2          Clothing
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 9995                    0                  0                  99
# 9996                    0                  0                  70
# 9997                    0                  0                  44
# 9998                    0                  0                  38
# 9999                    0                  0                  38
#
#       velocity_last_24h  cardholder_age  is_fraud
# 9995                  4              37         0
# 9996                  3              25         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   transaction_id       10000 non-null  int64
#  1   amount               10000 non-null  float64
#  2   transaction_hour     10000 non-null  int64
#  3   merchant_category    10000 non-null  object
#  4   foreign_transaction  10000 non-null  int64
#  5   location_mismatch    10000 non-null  int64
#  6   device_trust_score   10000 non-null  int64
#  7   velocity_last_24h    10000 non-null  int64
#  8   cardholder_age       10000 non-null  int64
#  9   is_fraud             10000 non-null  int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 781.4+ KB

# %%
df["location_mismatch"].value_counts()
# Out:
# location_mismatch
# 0    9143
# 1     857
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# transaction_id  amount  transaction_hour  merchant_category  foreign_transaction  location_mismatch  device_trust_score  velocity_last_24h  cardholder_age  is_fraud
# 9984            433.08  20                Grocery            0                    0                  83                  1                  44              0           1
# 9983            67.31   3                 Travel             0                    0                  74                  2                  51              0           1
# 9982            166.44  10                Food               0                    0                  95                  1                  30              0           1
# 9981            78.63   20                Electronics        0                    0                  47                  1                  40              0           1
# ...

# %%
df.isnull()
# Out:
#       transaction_id  amount  transaction_hour  merchant_category  \
# 0              False   False             False              False
# 1              False   False             False              False
# 2              False   False             False              False
# 3              False   False             False              False
# 4              False   False             False              False
# ...              ...     ...               ...                ...
# 9995           False   False             False              False
# 9996           False   False             False              False
# 9997           False   False             False              False
# 9998           False   False             False              False
# 9999           False   False             False              False
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 0                   False              False               False
# ...

# %%
df.fillna(1)
df
# Out:
#       transaction_id  amount  transaction_hour merchant_category  \
# 0                  1   84.47                22       Electronics
# 1                  2  541.82                 3            Travel
# 2                  3  237.01                17           Grocery
# 3                  4  164.33                 4           Grocery
# 4                  5   30.53                15              Food
# ...              ...     ...               ...               ...
# 9995            9996  350.91                22              Food
# 9996            9997  410.04                 5          Clothing
# 9997            9998  527.75                21       Electronics
# 9998            9999   91.20                 2       Electronics
# 9999           10000   44.06                 2          Clothing
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 0                       0                  0                  66
# ...

# %%
df["is_fraud"]=df["is_fraud"].replace(1,"True")
df["is_fraud"]=df["is_fraud"].replace(0,"False")
df
# Out:
#       transaction_id  amount  transaction_hour merchant_category  \
# 0                  1   84.47                22       Electronics
# 1                  2  541.82                 3            Travel
# 2                  3  237.01                17           Grocery
# 3                  4  164.33                 4           Grocery
# 4                  5   30.53                15              Food
# ...              ...     ...               ...               ...
# 9995            9996  350.91                22              Food
# 9996            9997  410.04                 5          Clothing
# 9997            9998  527.75                21       Electronics
# 9998            9999   91.20                 2       Electronics
# 9999           10000   44.06                 2          Clothing
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 0                       0                  0                  66
# ...

# %%
df = df.drop(columns=["merchant_category"])

# %%
from sklearn.preprocessing import LabelEncoder
coder=LabelEncoder()

# %%
df["is_fraud"]=df["is_fraud"].astype(str)
df["is_fraud"]=coder.fit_transform(df["is_fraud"])
df
# Out:
#       transaction_id  amount  transaction_hour  foreign_transaction  \
# 0                  1   84.47                22                    0
# 1                  2  541.82                 3                    1
# 2                  3  237.01                17                    0
# 3                  4  164.33                 4                    0
# 4                  5   30.53                15                    0
# ...              ...     ...               ...                  ...
# 9995            9996  350.91                22                    0
# 9996            9997  410.04                 5                    0
# 9997            9998  527.75                21                    0
# 9998            9999   91.20                 2                    0
# 9999           10000   44.06                 2                    0
#
#       location_mismatch  device_trust_score  velocity_last_24h  \
# 0                     0                  66                  3
# ...

# %%
df["amount"]=df["amount"].astype(str)
df["amount"]=coder.fit_transform(df["amount"])
df
# Out:
#       transaction_id  amount  transaction_hour  foreign_transaction  \
# 0                  1    8228                22                    0
# 1                  2    6781                 3                    1
# 2                  3    3469                17                    0
# 3                  4    1954                 4                    0
# 4                  5    4484                15                    0
# ...              ...     ...               ...                  ...
# 9995            9996    5118                22                    0
# 9996            9997    5785                 5                    0
# 9997            9998    6664                21                    0
# 9998            9999    8502                 2                    0
# 9999           10000    5996                 2                    0
#
#       location_mismatch  device_trust_score  velocity_last_24h  \
# 0                     0                  66                  3
# ...

# %%
# df["merchant_category"]=df["merchant_category"].astype(str)
# df["merchant_category"]=coder.fit_transform(df["merchant_category"])
# df

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["amount"],df["foreign_transaction"])

# %%
plt.bar(df['amount'],df['foreign_transaction'])
plt.xlabel("amount")
plt.ylabel("foreign_transaction")
plt.title("Bar Plot")
plt.show()

# %%
plt.stem(df['amount'],df['foreign_transaction'])
plt.xlabel("amount")
plt.ylabel("foreign_transaction")
plt.title("stem Plot")
plt.show()

# %%
plt.hist(df['amount'], bins=20)
plt.xlabel("amount")
plt.ylabel("Frequency")
plt.title("Histogram of Amount")
plt.show()

# %%
import seaborn as sus

# %%
sus.boxplot(x=df['amount'],y=df['foreign_transaction'])
plt.xlabel("amount")
plt.ylabel("foreign_transaction")
plt.title("Bax Plot")
plt.show()

# %%
sus.barplot(x=df['amount'],y=df['foreign_transaction'])
plt.xlabel("amount")
plt.ylabel("foreign_transaction")
plt.title("Bar Plot")
plt.show()

# %%
sus.lineplot(x=df['amount'],y=df['foreign_transaction'])
plt.xlabel("amount")
plt.ylabel("foreign_transaction")
plt.title("line Plot")
plt.show()

# %%
sus.scatterplot(x=df['amount'],y=df['foreign_transaction'])
plt.xlabel("amount")
plt.ylabel("foreign_transaction")
plt.title("scatter Plot")
plt.show()

# %%
sus.kdeplot(x=df['amount'],y=df['foreign_transaction'])
plt.xlabel("amount")
plt.ylabel("foreign_transaction")
plt.title("kde Plot")
plt.show()

# %%
x=df.drop("is_fraud",axis=1)
y=df["is_fraud"]

# %%
x

# %%
y

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.info()

# %%
x_test.info()

# %%
y_train.info()

# %%
y_test.info()

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)

# %%
pred=model.predict(x_test)
pred

# %%
accuracy=model.score(x_test,y_test)

# %%
accuracy

# %%
from sklearn.tree import DecisionTreeClassifier
model1=DecisionTreeClassifier()

# %%
model1.fit(x_train,y_train)

# %%
pred=model.predict(x_test)

# %%
pred

# %%
accuracy=model1.score(x_test,y_test)

# %%
accuracy

# %%
from sklearn.svm import SVC
model2=SVC()

# %%
model2.fit(x_train,y_train)

# %%
model.predict(x_test)

# %%
accuracy=model2.score(x_test,y_test)

# %%
accuracy

# %%
from sklearn.ensemble import RandomForestClassifier
model3=RandomForestClassifier()

# %%
model3.fit(x_train,y_train)

# %%
model3.predict(x_test)

# %%
model.score(x_test,y_test)
